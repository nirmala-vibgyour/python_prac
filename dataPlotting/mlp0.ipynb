# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("titanic.csv")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
# plots the dataframe
# float and int cols are plotted
# line plot of each cols with diff color
df.plot()
plt.show()

# %%
# subplots, size of each, wheather or not common x and y axis
df.plot(subplots = True, figsize = (12, 15), sharex = False, sharey = False)
plt.show()

# %%
# customised graph divisions
xticks = [ x for x in range(0, 901, 50)]
yticks = [ y for y in range(0, 81, 5)]

# %%
df.age.plot(figsize = (10, 6), fontsize = 10, c = 'brown', linestyle = "-", xlim = (0, 900) , ylim = (0, 80), xticks = xticks, yticks = yticks, rot = 45)
plt.title("Titanic - Ages", fontsize = 15)
plt.legend(loc = "best", fontsize = 15)
plt.xlabel("Passenger count", fontsize = 15)
plt.ylabel("Age", fontsize = 12)
plt.grid()
plt.show()

# %%
# diff forms of graph
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8')

# %% [markdown]
# HISTOGRAM

# %%
df.plot(kind = "hist", figsize = (12, 8), fontsize = 15)
plt.show()

# %%
df.age.plot(kind = "hist", figsize = (12, 8), fontsize = 15, bins = 80)
plt.legend(loc = "best", fontsize = 15)
plt.show()

# %%
df.age.hist(figsize = (12, 8), xlabelsize = 15, ylabelsize = 15, bins = 80, edgecolor='none', color='#496fad')
plt.show()

# %%
plt.figure(figsize = (12, 8))
plt.hist(df.age.dropna(), bins = 80, density = True , cumulative = True, edgecolor='none', color='#496fad')
plt.xlim(-5, 85)
plt.ylim(0.0, 1.1)
plt.show()

# %% [markdown]
# Barchart and Piecharts

# %%
df1 = pd.read_csv("summer_2012.csv", index_col = "Country")
df1
# Out:
#          Medal
# Country
# USA        250
# RUS        130
# CHN        128
# GBR        126
# AUS        114
# GER         94
# JPN         84
# FRA         82
# NED         69
# ITA         68
# ESP         65
# KOR         63
# BRA         59
# CAN         57
# CRO         35
# HUN         26
# MEX         26
# NZL         26
# JAM         25
# UKR         25
# Others     393

# %%
colors = [
    'b',    # Blue
    'g',    # Green
    'r',    # Red
    'c',    # Cyan
    'm',    # Magenta
    'y',    # Yellow
    'k',    # Black
    'w',    # White
    'orange',
    'purple',
    'brown',
    'pink',
    'gray',
    'olive',
    'teal',
    'navy',
    'maroon',
    'gold',
    'silver',
    'lightblue',
    'lightgreen',
    'lightcoral'
]
df1.plot(kind = "bar", figsize = (12, 8), fontsize = 12, rot = 45, color = "c" )
plt.show()
df1.shape
# Out:
# (21, 1)

# %%
df1.plot(kind = "barh", figsize = (12, 8), fontsize = 12, color = "c")
plt.show()

# %%
# subplots is required here
df1.plot(kind = "pie", figsize = (12, 8), fontsize = 12, subplots = True, rot = 45)
plt.legend().set_visible(False)
plt.show()

# %% [markdown]
# Scatterp plot

# %%
plt.style.use("seaborn-v0_8")

# %%
df.plot(kind = "scatter", figsize = (12, 8), x = "age", y = "fare", c = "pclass", marker = "D", s = 20, colormap = "cool", edgecolor = None)
plt.xlim(-5, 85)
plt.show()
