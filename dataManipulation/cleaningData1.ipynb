# %% [markdown]
# ## **First Inspection/ Handling inconsistent Data**

# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic_imp.csv")

# %%
titanic.head()
# Out:
#   Survived  Class  Gender   Age  SipSp  ParCh      Fare Emb Deck
# 0        0      3    male  22.0      1      0     $7.25   S  NaN
# 1        1      1  female  38.0      1      0  $71.2833   C    C
# 2        1      3  female  26.0      0      0    $7.925   S  NaN
# 3        1      1  female  35.0      1      0     $53.1   S    C
# 4        0      3    male  35.0      0      0     $8.05   S  NaN

# %%
titanic.tail()
# Out:
#     Survived  Class Gender   Age  SipSp  ParCh     Fare Emb Deck
# 889        1      1   male  26.0      0      0    $30.0   C    C
# 890        0      3   male  32.0      0      0    $7.75   Q  NaN
# 891        0      2   male  24.0      0      0    $10.5   S  NaN
# 892        0      3   male  34.0      1      1    $14.4   S  NaN
# 893        0      3   male  36.0      0      0  $7.8958   S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  894 non-null    object
#  1   Class     894 non-null    int64
#  2   Gender    894 non-null    object
#  3   Age       758 non-null    object
#  4   SipSp     894 non-null    int64
#  5   ParCh     894 non-null    int64
#  6   Fare      894 non-null    object
#  7   Emb       892 non-null    object
#  8   Deck      203 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 63.0+ KB

# %%
titanic.describe()
# Out:
#             Class       SipSp       ParCh
# count  894.000000  894.000000  894.000000
# mean     2.309843    0.522371    0.381432
# std      0.835370    1.101283    0.805171
# min      1.000000    0.000000    0.000000
# 25%      2.000000    0.000000    0.000000
# 50%      3.000000    0.000000    0.000000
# 75%      3.000000    1.000000    0.000000
# max      3.000000    8.000000    6.000000

# %%
titanic[["Survived", "Gender", "Age", "Fare", "Emb", "Deck"]].describe()
# Out:
#        Survived Gender           Age   Fare  Emb Deck
# count       894    894           758    894  892  203
# unique        4      2            92    248    3    7
# top           0   male  Missing Data  $8.05    S    C
# freq        551    580            41     43  647   59

# %%
titanic.Survived.unique()
# Out:
# array(['0', '1', 1, 0], dtype=object)

# %%
titanic.Survived.value_counts()
# Out:
# Survived
# 0    551
# 1    341
# 1      1
# 0      1
# Name: count, dtype: int64

# %%
# titanic.Survived.replace(to_replace = ["yes", "no"], value = [1, 0], inplace = True) // old

# %%
titanic["Survived"].replace({"1": 1, "0": 0}, inplace = True)
# Out:
# C:\Users\nirma\AppData\Local\Temp\ipykernel_7128\2495786816.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   titanic["Survived"].replace({"1": 1, "0": 0}, inplace = True)

# %%
titanic.Survived.unique()  # Here, all the values in survived columns are changed to int: called downcasting as a result of replace method(used twice). For such thing astype() method is used.
# Out:
# array([0, 1], dtype=int64)

# %%
titanic.Survived.value_counts()
# Out:
# Survived
# 0    552
# 1    342
# Name: count, dtype: int64

# %%
summer = pd.read_csv("summer_imp.csv")

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline          Athlete Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming        HAJOS, Alfred      HUN    Men
# 1  1896  Athens  Aquatics   Swimming     HERSCHMANN, Otto      AUT    Men
# 2  1896  Athens  Aquatics   Swimming    DRIVAS, Dimitrios      GRE    Men
# 3  1896  Athens  Aquatics   Swimming   Malokinis, Ioannis      GRE    Men
# 4  1896  Athens  Aquatics   Swimming   Chasapis, Spiridon      GRE    Men
#
#                         Event       Medal
# 0              100M Freestyle  Gold Medal
# 1              100M Freestyle      Silver
# 2  100M Freestyle For Sailors      Bronze
# 3  100M Freestyle For Sailors  Gold Medal
# 4  100M Freestyle For Sailors      Silver

# %%
summer.tail()
# Out:
#        Year    City      Sport           Discipline  \
# 31165  2012  London  Wrestling  Wrestling Freestyle
# 31166  2012  London  Wrestling  Wrestling Freestyle
# 31167  2012  London  Wrestling  Wrestling Freestyle
# 31168  2012  London  Wrestling  Wrestling Freestyle
# 31169  2012  London  Wrestling  Wrestling Freestyle
#
#                       Athlete Name Country Gender     Event   Medal
# 31165          JANIKOWSKI, Damian      POL    Men  Wg 84 KG  Bronze
# 31166   REZAEI, Ghasem Gholamreza      IRI    Men  Wg 96 KG    Gold
# 31167              TOTROV, Rustam      RUS    Men  Wg 96 KG  Silver
# 31168           ALEKSANYAN, Artur      ARM    Men  Wg 96 KG  Bronze
# 31169              LIDBERG, Jimmy      SWE    Men  Wg 96 KG  Bronze

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31170 entries, 0 to 31169
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          31170 non-null  int64
#  1   City          31170 non-null  object
#  2   Sport         31170 non-null  object
#  3   Discipline    31170 non-null  object
#  4   Athlete Name  31170 non-null  object
#  5   Country       31166 non-null  object
#  6   Gender        31170 non-null  object
#  7   Event         31170 non-null  object
#  8   Medal         31170 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer.describe()
# Out:
#                Year
# count  31170.000000
# mean    1970.483157
# std       33.158454
# min     1896.000000
# 25%     1948.000000
# 50%     1980.000000
# 75%     2000.000000
# max     2012.000000

# %%
summer.describe(include="all")
# Out:
#                 Year    City     Sport Discipline       Athlete Name Country  \
# count   31170.000000   31170     31170      31170              31170   31166
# unique           NaN      22        43         67              22763     147
# top              NaN  London  Aquatics  Athletics   PHELPS, Michael      USA
# freq             NaN    3567      4170       3639                 22    4586
# mean     1970.483157     NaN       NaN        NaN                NaN     NaN
# std        33.158454     NaN       NaN        NaN                NaN     NaN
# min      1896.000000     NaN       NaN        NaN                NaN     NaN
# 25%      1948.000000     NaN       NaN        NaN                NaN     NaN
# 50%      1980.000000     NaN       NaN        NaN                NaN     NaN
# 75%      2000.000000     NaN       NaN        NaN                NaN     NaN
# max      2012.000000     NaN       NaN        NaN                NaN     NaN
#
#        Gender     Event  Medal
# ...

# %%
summer.Athlete Name
# Out:
#   Cell In[36], line 1
#     summer.Athlete Name
#                    ^
# SyntaxError: invalid syntax

# %%
summer.rename(columns = {"Athlete Name" : "Athlete_Name"}, inplace = True)

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline          Athlete_Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming        HAJOS, Alfred      HUN    Men
# 1  1896  Athens  Aquatics   Swimming     HERSCHMANN, Otto      AUT    Men
# 2  1896  Athens  Aquatics   Swimming    DRIVAS, Dimitrios      GRE    Men
# 3  1896  Athens  Aquatics   Swimming   Malokinis, Ioannis      GRE    Men
# 4  1896  Athens  Aquatics   Swimming   Chasapis, Spiridon      GRE    Men
#
#                         Event       Medal
# 0              100M Freestyle  Gold Medal
# 1              100M Freestyle      Silver
# 2  100M Freestyle For Sailors      Bronze
# 3  100M Freestyle For Sailors  Gold Medal
# 4  100M Freestyle For Sailors      Silver

# %%
summer.Medal.value_counts()
# Out:
# Medal
# Gold          10483
# Bronze        10372
# Silver        10311
# Gold Medal        4
# Name: count, dtype: int64

# %%
# summer.Medal.replace(to_replace = "Gold Medal", value = "Gold", inplace = True) # old

# %%
summer["Medal"].replace({"Gold Medal": "Gold"}, inplace = True) # new

# %%
summer.Medal.unique()
# Out:
# array(['Gold', 'Silver', 'Bronze'], dtype=object)

# %%
summer.iloc[:, 1:].describe()
# Out:
#           City     Sport Discipline       Athlete_Name Country Gender  \
# count    31170     31170      31170              31170   31166  31170
# unique      22        43         67              22763     147      2
# top     London  Aquatics  Athletics   PHELPS, Michael      USA    Men
# freq      3567      4170       3639                 22    4586  22751
#
#            Event  Medal
# count      31170  31170
# unique       666      3
# top     Football   Gold
# freq        1497  10487

# %% [markdown]
# # **String Operations**

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  894 non-null    int64
#  1   Class     894 non-null    int64
#  2   Gender    894 non-null    object
#  3   Age       758 non-null    object
#  4   SipSp     894 non-null    int64
#  5   ParCh     894 non-null    int64
#  6   Fare      894 non-null    object
#  7   Emb       892 non-null    object
#  8   Deck      203 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 63.0+ KB

# %%
titanic.describe(include= "all")
# Out:
#           Survived       Class Gender           Age       SipSp       ParCh  \
# count   894.000000  894.000000    894           758  894.000000  894.000000
# unique         NaN         NaN      2            92         NaN         NaN
# top            NaN         NaN   male  Missing Data         NaN         NaN
# freq           NaN         NaN    580            41         NaN         NaN
# mean      0.382550    2.309843    NaN           NaN    0.522371    0.381432
# std       0.486282    0.835370    NaN           NaN    1.101283    0.805171
# min       0.000000    1.000000    NaN           NaN    0.000000    0.000000
# 25%       0.000000    2.000000    NaN           NaN    0.000000    0.000000
# 50%       0.000000    3.000000    NaN           NaN    0.000000    0.000000
# 75%       1.000000    3.000000    NaN           NaN    1.000000    0.000000
# max       1.000000    3.000000    NaN           NaN    8.000000    6.000000
#
#          Fare  Emb Deck
# count     894  892  203
# ...

# %%
titanic.Fare.unique()
# Out:
# array(['$7.25', '$71.2833', '$7.925', '$53.1', '$8.05', '$8.4583',
#        '$51.8625', '$21.075', '$11.1333', '$30.0708', '$16.7', '$26.55',
#        '$31.275', '$7.8542', '$16.0', '$29.125', '$13.0', '$18.0',
#        '$7.225', '$26.0', '$8.0292', '$35.5', '$31.3875', '$263.0',
#        '$7.8792', '$7.8958', '$27.7208', '$146.5208', '$7.75', '$10.5',
#        '$82.1708', '$52.0', '$7.2292', '$11.2417', '$9.475', '$21.0',
#        '$41.5792', '$15.5', '$21.6792', '$17.8', '$39.6875', '$7.8',
#        '$76.7292', '$61.9792', '$27.75', '$46.9', '$80.0', '$83.475',
#        '$27.9', '$15.2458', '$8.1583', '$8.6625', '$73.5', '$14.4542',
#        '$56.4958', '$7.65', '$29.0', '$12.475', '$9.0', '$9.5', '$7.7875',
#        '$47.1', '$15.85', '$34.375', '$61.175', '$20.575', '$34.6542',
#        '$63.3583', '$23.0', '$77.2875', '$8.6542', '$7.775', '$24.15',
#        '$9.825', '$14.4583', '$247.5208', '$7.1417', '$22.3583', '$6.975',
# ...

# %%
titanic.Fare = titanic.Fare.str.replace("$", "")

# %%
titanic.Fare.head()
# Out:
# 0       7.25
# 1    71.2833
# 2      7.925
# 3       53.1
# 4       8.05
# Name: Fare, dtype: object

# %%
pd.to_numeric(titanic.Fare)
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 889    30.0000
# 890     7.7500
# 891    10.5000
# 892    14.4000
# 893     7.8958
# Name: Fare, Length: 894, dtype: float64

# %%
summer.head(20)
# Out:
#     Year    City      Sport Discipline             Athlete_Name Country  \
# 0   1896  Athens   Aquatics   Swimming           HAJOS, Alfred      HUN
# 1   1896  Athens   Aquatics   Swimming        HERSCHMANN, Otto      AUT
# 2   1896  Athens   Aquatics   Swimming       DRIVAS, Dimitrios      GRE
# 3   1896  Athens   Aquatics   Swimming      Malokinis, Ioannis      GRE
# 4   1896  Athens   Aquatics   Swimming      Chasapis, Spiridon      GRE
# 5   1896  Athens   Aquatics   Swimming   Chorophas, Efstathios      GRE
# 6   1896  Athens   Aquatics   Swimming           Hajos, Alfred      HUN
# 7   1896  Athens   Aquatics   Swimming        Andreou, Joannis      GRE
# 8   1896  Athens   Aquatics   Swimming   Chorophas, Efstathios      GRE
# 9   1896  Athens   Aquatics   Swimming           Neumann, Paul      AUT
# 10  1896  Athens   Aquatics   Swimming       Pepanos, Antonios      GRE
# 11  1896  Athens  Athletics  Athletics           Lane, Francis      USA
# ...

# %%
summer.Athlete_Name = summer.Athlete_Name.str.title()

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline          Athlete_Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming        Hajos, Alfred      HUN    Men
# 1  1896  Athens  Aquatics   Swimming     Herschmann, Otto      AUT    Men
# 2  1896  Athens  Aquatics   Swimming    Drivas, Dimitrios      GRE    Men
# 3  1896  Athens  Aquatics   Swimming   Malokinis, Ioannis      GRE    Men
# 4  1896  Athens  Aquatics   Swimming   Chasapis, Spiridon      GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.loc[summer.Athlete_Name == "Hajos, Alfred"]
# Out:
# Empty DataFrame
# Columns: [Year, City, Sport, Discipline, Athlete_Name, Country, Gender, Event, Medal]
# Index: []

# %%
summer.iloc[0,4]
# Out:
# ' Hajos, Alfred '

# %%
summer.loc[summer.Athlete_Name.str.contains("Hajos, Alfred")]
# Out:
#    Year    City     Sport Discipline     Athlete_Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming   Hajos, Alfred      HUN    Men
# 6  1896  Athens  Aquatics   Swimming   Hajos, Alfred      HUN    Men
#
#              Event Medal
# 0   100M Freestyle  Gold
# 6  1200M Freestyle  Gold

# %%
summer.Athlete_Name = summer.Athlete_Name.str.strip()

# %%
summer.iloc[0,4]
# Out:
# 'Hajos, Alfred'

# %%
summer.loc[summer.Athlete_Name == "Phelps, Michael"]
# Out:
#        Year     City     Sport Discipline     Athlete_Name Country Gender  \
# 25229  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25257  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25262  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25269  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25281  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25290  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25329  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 25365  2004   Athens  Aquatics   Swimming  Phelps, Michael     USA    Men
# 27228  2008  Beijing  Aquatics   Swimming  Phelps, Michael     USA    Men
# 27256  2008  Beijing  Aquatics   Swimming  Phelps, Michael     USA    Men
# 27262  2008  Beijing  Aquatics   Swimming  Phelps, Michael     USA    Men
# 27268  2008  Beijing  Aquatics   Swimming  Phelps, Michael     USA    Men
# ...

# %% [markdown]
# # **Changing Datatypes of columns with astype()**

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  894 non-null    int64
#  1   Class     894 non-null    int64
#  2   Gender    894 non-null    object
#  3   Age       758 non-null    object
#  4   SipSp     894 non-null    int64
#  5   ParCh     894 non-null    int64
#  6   Fare      894 non-null    object
#  7   Emb       892 non-null    object
#  8   Deck      203 non-null    object
# dtypes: int64(4), object(5)
# memory usage: 63.0+ KB

# %%
pd.to_numeric(titanic.Fare)
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 889    30.0000
# 890     7.7500
# 891    10.5000
# 892    14.4000
# 893     7.8958
# Name: Fare, Length: 894, dtype: float64

# %%
titanic.Fare.astype("float")
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 889    30.0000
# 890     7.7500
# 891    10.5000
# 892    14.4000
# 893     7.8958
# Name: Fare, Length: 894, dtype: float64

# %%
titanic.Fare = titanic.Fare.astype("float")

# %%
titanic.Survived = titanic.Survived.astype("int")

# %%
titanic["Age"] = titanic.Age.astype("float")   # missing data type
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 titanic["Age"] = titanic.Age.astype("float")
#
# File ~\miniconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\miniconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
# ...

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31170 entries, 0 to 31169
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          31170 non-null  int64
#  1   City          31170 non-null  object
#  2   Sport         31170 non-null  object
#  3   Discipline    31170 non-null  object
#  4   Athlete_Name  31170 non-null  object
#  5   Country       31166 non-null  object
#  6   Gender        31170 non-null  object
#  7   Event         31170 non-null  object
#  8   Medal         31170 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %% [markdown]
# # **Intro to NA Values**

# %%
import numpy as np

# %%
sales = pd.read_csv("./Course_Materials_Part2/Video_Lecture_NBs/sales.csv", index_col = 0)

# %%
sales
# Out:
#         Mon  Tue  Wed   Thu   Fri
# Steven   34   27   15   NaN   NaN
# Mike     45    9   74  87.0  12.0
# Andi     17   33   54   8.0  29.0
# Paul     87   67   27  45.0   7.0

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Steven to Paul
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mon     4 non-null      int64
#  1   Tue     4 non-null      int64
#  2   Wed     4 non-null      int64
#  3   Thu     3 non-null      float64
#  4   Fri     3 non-null      float64
# dtypes: float64(2), int64(3)
# memory usage: 192.0+ bytes

# %%
sales.iloc[:,3:5]
# Out:
#          Thu   Fri
# Steven   NaN   NaN
# Mike    87.0  12.0
# Andi     8.0  29.0
# Paul    45.0   7.0

# %%
sales.loc["Steven", "Thu"]
# Out:
# nan

# %%
sales.iloc[1, 1] = None

# %%
sales
# Out:
#         Mon   Tue  Wed   Thu   Fri
# Steven   34  27.0   15   NaN   NaN
# Mike     45   NaN   74  87.0  12.0
# Andi     17  33.0   54   8.0  29.0
# Paul     87  67.0   27  45.0   7.0

# %%
sales.iloc[2, 2] = np.nan

# %%
sales
# Out:
#         Mon   Tue   Wed   Thu   Fri
# Steven   34  27.0  15.0   NaN   NaN
# Mike     45   NaN  74.0  87.0  12.0
# Andi     17  33.0   NaN   8.0  29.0
# Paul     87  67.0  27.0  45.0   7.0

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Steven to Paul
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mon     4 non-null      int64
#  1   Tue     3 non-null      float64
#  2   Wed     3 non-null      float64
#  3   Thu     3 non-null      float64
#  4   Fri     3 non-null      float64
# dtypes: float64(4), int64(1)
# memory usage: 192.0+ bytes

# %%
sales.iloc[0,3] = ' '
# Out:
# C:\Users\nirma\AppData\Local\Temp\ipykernel_7128\495279524.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value ' ' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   sales.iloc[0,3] = ' '

# %%
sales
# Out:
#         Mon   Tue   Wed   Thu   Fri
# Steven   34  27.0  15.0         NaN
# Mike     45   NaN  74.0  87.0  12.0
# Andi     17  33.0   NaN   8.0  29.0
# Paul     87  67.0  27.0  45.0   7.0

# %%
sales.iloc[0,3] = ' '

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Steven to Paul
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Mon     4 non-null      int64
#  1   Tue     3 non-null      float64
#  2   Wed     3 non-null      float64
#  3   Thu     4 non-null      object
#  4   Fri     3 non-null      float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 192.0+ bytes

# %% [markdown]
# # **Detecting Missing Values**

# %%
titanic.head(10)
# Out:
#    Survived  Class  Gender           Age  SipSp  ParCh     Fare Emb Deck
# 0         0      3    male          22.0      1      0   7.2500   S  NaN
# 1         1      1  female          38.0      1      0  71.2833   C    C
# 2         1      3  female          26.0      0      0   7.9250   S  NaN
# 3         1      1  female          35.0      1      0  53.1000   S    C
# 4         0      3    male          35.0      0      0   8.0500   S  NaN
# 5         0      3    male  Missing Data      0      0   8.4583   Q  NaN
# 6         0      1    male          54.0      0      0  51.8625   S    E
# 7         0      3    male           2.0      3      1  21.0750   S  NaN
# 8         1      3  female          27.0      0      2  11.1333   S  NaN
# 9         1      2  female          14.0      1      0  30.0708   C  NaN

# %%
titanic.tail(10)
# Out:
#      Survived  Class  Gender   Age  SipSp  ParCh     Fare Emb Deck
# 884         0      3    male  25.0      0      0   7.0500   S  NaN
# 885         0      3  female  39.0      0      5  29.1250   Q  NaN
# 886         0      2    male  27.0      0      0  13.0000   S  NaN
# 887         1      1  female  19.0      0      0  30.0000   S    B
# 888         0      3  female   NaN      1      2  23.4500   S  NaN
# 889         1      1    male  26.0      0      0  30.0000   C    C
# 890         0      3    male  32.0      0      0   7.7500   Q  NaN
# 891         0      2    male  24.0      0      0  10.5000   S  NaN
# 892         0      3    male  34.0      1      1  14.4000   S  NaN
# 893         0      3    male  36.0      0      0   7.8958   S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  894 non-null    int32
#  1   Class     894 non-null    int64
#  2   Gender    894 non-null    object
#  3   Age       758 non-null    object
#  4   SipSp     894 non-null    int64
#  5   ParCh     894 non-null    int64
#  6   Fare      894 non-null    float64
#  7   Emb       892 non-null    object
#  8   Deck      203 non-null    object
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 59.5+ KB

# %%
titanic.isna()
# Out:
#      Survived  Class  Gender    Age  SipSp  ParCh   Fare    Emb   Deck
# 0       False  False   False  False  False  False  False  False   True
# 1       False  False   False  False  False  False  False  False  False
# 2       False  False   False  False  False  False  False  False   True
# 3       False  False   False  False  False  False  False  False  False
# 4       False  False   False  False  False  False  False  False   True
# ..        ...    ...     ...    ...    ...    ...    ...    ...    ...
# 889     False  False   False  False  False  False  False  False  False
# 890     False  False   False  False  False  False  False  False   True
# 891     False  False   False  False  False  False  False  False   True
# 892     False  False   False  False  False  False  False  False   True
# 893     False  False   False  False  False  False  False  False   True
#
# [894 rows x 9 columns]

# %%
titanic.isna().sum(axis = 0)  # axis = 1 give count of nan rowise
# Out:
# Survived      0
# Class         0
# Gender        0
# Age         136
# SipSp         0
# ParCh         0
# Fare          0
# Emb           2
# Deck        691
# dtype: int64

# %%
titanic.isna().any(axis = 0)
# Out:
# Survived    False
# Class       False
# Gender      False
# Age          True
# SipSp       False
# ParCh       False
# Fare        False
# Emb          True
# Deck         True
# dtype: bool

# %%
titanic[titanic.isna().any(axis = 1)]
# Out:
#      Survived  Class  Gender           Age  SipSp  ParCh     Fare Emb Deck
# 0           0      3    male          22.0      1      0   7.2500   S  NaN
# 2           1      3  female          26.0      0      0   7.9250   S  NaN
# 4           0      3    male          35.0      0      0   8.0500   S  NaN
# 5           0      3    male  Missing Data      0      0   8.4583   Q  NaN
# 7           0      3    male           2.0      3      1  21.0750   S  NaN
# ..        ...    ...     ...           ...    ...    ...      ...  ..  ...
# 888         0      3  female           NaN      1      2  23.4500   S  NaN
# 890         0      3    male          32.0      0      0   7.7500   Q  NaN
# 891         0      2    male          24.0      0      0  10.5000   S  NaN
# 892         0      3    male          34.0      1      1  14.4000   S  NaN
# 893         0      3    male          36.0      0      0   7.8958   S  NaN
#
# [707 rows x 9 columns]

# %%
titanic.notna()
# Out:
#      Survived  Class  Gender   Age  SipSp  ParCh  Fare   Emb   Deck
# 0        True   True    True  True   True   True  True  True  False
# 1        True   True    True  True   True   True  True  True   True
# 2        True   True    True  True   True   True  True  True  False
# 3        True   True    True  True   True   True  True  True   True
# 4        True   True    True  True   True   True  True  True  False
# ..        ...    ...     ...   ...    ...    ...   ...   ...    ...
# 889      True   True    True  True   True   True  True  True   True
# 890      True   True    True  True   True   True  True  True  False
# 891      True   True    True  True   True   True  True  True  False
# 892      True   True    True  True   True   True  True  True  False
# 893      True   True    True  True   True   True  True  True  False
#
# [894 rows x 9 columns]

# %%
titanic.notna().sum(axis = 0)
# Out:
# Survived    894
# Class       894
# Gender      894
# Age         758
# SipSp       894
# ParCh       894
# Fare        894
# Emb         892
# Deck        203
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (8, 6))
sns.heatmap(titanic.notna())
plt.show()

# %%
titanic.Age.value_counts(dropna = False)
# Out:
# Age
# NaN             136
# Missing Data     41
# 24.0             31
# 22.0             27
# 18.0             26
#                ...
# 55.5              1
# 66.0              1
# 0.92              1
# 23.5              1
# 74.0              1
# Name: count, Length: 93, dtype: int64

# %%
titanic.Age.replace({"Missing Data": np.nan}, inplace = True)

# %%
titanic.Age.value_counts(dropna = False)
# Out:
# Age
# NaN     177
# 24.0     31
# 22.0     27
# 18.0     26
# 28.0     25
#        ...
# 55.5      1
# 66.0      1
# 0.92      1
# 23.5      1
# 74.0      1
# Name: count, Length: 92, dtype: int64

# %%
titanic.Age = titanic.Age.astype("float")

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  894 non-null    int32
#  1   Class     894 non-null    int64
#  2   Gender    894 non-null    object
#  3   Age       717 non-null    float64
#  4   SipSp     894 non-null    int64
#  5   ParCh     894 non-null    int64
#  6   Fare      894 non-null    float64
#  7   Emb       892 non-null    object
#  8   Deck      203 non-null    object
# dtypes: float64(2), int32(1), int64(3), object(3)
# memory usage: 59.5+ KB

# %%
summer[summer.isna().any(axis = 1)]
# Out:
#        Year    City          Sport           Discipline     Athlete_Name  \
# 29608  2012  London      Athletics            Athletics          Pending
# 31077  2012  London  Weightlifting        Weightlifting          Pending
# 31096  2012  London  Weightlifting        Weightlifting          Pending
# 31115  2012  London      Wrestling  Wrestling Freestyle  Kudukhov, Besik
#
#       Country Gender     Event   Medal
# 29608     NaN  Women     1500M    Gold
# 31077     NaN  Women      63KG    Gold
# 31096     NaN    Men      94KG  Silver
# 31115     NaN    Men  Wf 60 KG  Silver

# %%
summer.Country.value_counts(dropna = False) # not yeilding cause the NAN values are in the middle
# Out:
# Country
# USA    4586
# URS    2049
# GBR    1720
# FRA    1397
# GER    1305
#        ...
# DJI       1
# AHO       1
# ISV       1
# BAR       1
# GAB       1
# Name: count, Length: 148, dtype: int64

# %% [markdown]
# # **Removing Missing Values with dropna()**

# %%
titanic.head()
# Out:
#    Survived  Class  Gender   Age  SipSp  ParCh     Fare Emb Deck
# 0         0      3    male  22.0      1      0   7.2500   S  NaN
# 1         1      1  female  38.0      1      0  71.2833   C    C
# 2         1      3  female  26.0      0      0   7.9250   S  NaN
# 3         1      1  female  35.0      1      0  53.1000   S    C
# 4         0      3    male  35.0      0      0   8.0500   S  NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  894 non-null    int32
#  1   Class     894 non-null    int64
#  2   Gender    894 non-null    object
#  3   Age       717 non-null    float64
#  4   SipSp     894 non-null    int64
#  5   ParCh     894 non-null    int64
#  6   Fare      894 non-null    float64
#  7   Emb       892 non-null    object
#  8   Deck      203 non-null    object
# dtypes: float64(2), int32(1), int64(3), object(3)
# memory usage: 59.5+ KB

# %%
titanic[titanic.Emb.isna()]
# Out:
#      Survived  Class  Gender   Age  SipSp  ParCh  Fare  Emb Deck
# 61          1      1  female  38.0      0      0  80.0  NaN    B
# 829         1      1  female  62.0      0      0  80.0  NaN    B

# %%
titanic.Age.value_counts(dropna = False)
# Out:
# Age
# NaN      177
# 24.00     31
# 22.00     27
# 18.00     26
# 28.00     25
#         ...
# 55.50      1
# 66.00      1
# 0.92       1
# 23.50      1
# 74.00      1
# Name: count, Length: 92, dtype: int64

# %%
titanic.Age.mean(skipna = True) # false: gives the false value
# Out:
# 30.718507670850766

# %%
titanic.shape
# Out:
# (894, 9)

# %%
titanic.dropna().shape # drops col or row with atleast one nan value
# Out:
# (182, 9)

# %%
titanic.dropna(axis = 1, how = "any").shape
# Out:
# (894, 6)

# %%
titanic.dropna(axis = 0, how = "any").shape
# Out:
# (182, 9)

# %%
titanic.dropna(axis = 1, how = "all").shape
# Out:
# (894, 9)

# %%
titanic.dropna(axis = 0, how = "all").shape
# Out:
# (894, 9)

# %%
titanic.dropna(axis = 0, thresh = 8).shape
# Out:
# (736, 9)

# %%
titanic.dropna(axis = 1, thresh = 500, inplace = True)

# %%
titanic.head()
# Out:
#    Survived  Class  Gender   Age  SipSp  ParCh     Fare Emb
# 0         0      3    male  22.0      1      0   7.2500   S
# 1         1      1  female  38.0      1      0  71.2833   C
# 2         1      3  female  26.0      0      0   7.9250   S
# 3         1      1  female  35.0      1      0  53.1000   S
# 4         0      3    male  35.0      0      0   8.0500   S

# %%
titanic.shape
# Out:
# (894, 8)

# %%
titanic.dropna(axis = 0, subset = ["Survived", "Class", "Gender", "Age"], thresh = 4).shape
# Out:
# (717, 8)

# %%
summer.head()
# Out:
#    Year    City     Sport Discipline        Athlete_Name Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       Hajos, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    Herschmann, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   Drivas, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  Malokinis, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  Chasapis, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31170 entries, 0 to 31169
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          31170 non-null  int64
#  1   City          31170 non-null  object
#  2   Sport         31170 non-null  object
#  3   Discipline    31170 non-null  object
#  4   Athlete_Name  31170 non-null  object
#  5   Country       31166 non-null  object
#  6   Gender        31170 non-null  object
#  7   Event         31170 non-null  object
#  8   Medal         31170 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
summer[summer.isna().any(axis = 1)]
# Out:
#        Year    City          Sport           Discipline     Athlete_Name  \
# 29608  2012  London      Athletics            Athletics          Pending
# 31077  2012  London  Weightlifting        Weightlifting          Pending
# 31096  2012  London  Weightlifting        Weightlifting          Pending
# 31115  2012  London      Wrestling  Wrestling Freestyle  Kudukhov, Besik
#
#       Country Gender     Event   Medal
# 29608     NaN  Women     1500M    Gold
# 31077     NaN  Women      63KG    Gold
# 31096     NaN    Men      94KG  Silver
# 31115     NaN    Men  Wf 60 KG  Silver

# %%
summer.dropna(inplace = True)

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31166 entries, 0 to 31169
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          31166 non-null  int64
#  1   City          31166 non-null  object
#  2   Sport         31166 non-null  object
#  3   Discipline    31166 non-null  object
#  4   Athlete_Name  31166 non-null  object
#  5   Country       31166 non-null  object
#  6   Gender        31166 non-null  object
#  7   Event         31166 non-null  object
#  8   Medal         31166 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.4+ MB

# %% [markdown]
# # **Replacing Missing Values with fillna()**

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  894 non-null    int32
#  1   Class     894 non-null    int64
#  2   Gender    894 non-null    object
#  3   Age       717 non-null    float64
#  4   SipSp     894 non-null    int64
#  5   ParCh     894 non-null    int64
#  6   Fare      894 non-null    float64
#  7   Emb       892 non-null    object
# dtypes: float64(2), int32(1), int64(3), object(2)
# memory usage: 52.5+ KB

# %%
titanic.isna().any(axis = 1).head(40)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26     True
# 27    False
# 28     True
# 29     True
# 30    False
# 31     True
# 32     True
# 33    False
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# dtype: bool

# %%
titanic.Age.mean()
# Out:
# 30.718507670850766

# %%
mean = round(titanic.Age.mean(), 1)
mean
# Out:
# 30.7

# %%
titanic.Age.fillna(mean, inplace = True) # old

# %%
titanic["Age"] = titanic["Age"].fillna(mean)

# %%
titanic.head(20)
# Out:
#     Survived  Class  Gender   Age  SipSp  ParCh     Fare Emb
# 0          0      3    male  22.0      1      0   7.2500   S
# 1          1      1  female  38.0      1      0  71.2833   C
# 2          1      3  female  26.0      0      0   7.9250   S
# 3          1      1  female  35.0      1      0  53.1000   S
# 4          0      3    male  35.0      0      0   8.0500   S
# 5          0      3    male  30.7      0      0   8.4583   Q
# 6          0      1    male  54.0      0      0  51.8625   S
# 7          0      3    male   2.0      3      1  21.0750   S
# 8          1      3  female  27.0      0      2  11.1333   S
# 9          1      2  female  14.0      1      0  30.0708   C
# 10         1      3  female   4.0      1      1  16.7000   S
# 11         1      1  female  58.0      0      0  26.5500   S
# 12         0      3    male  20.0      0      0   8.0500   S
# 13         0      3    male  39.0      1      5  31.2750   S
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 894 entries, 0 to 893
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  894 non-null    int32
#  1   Class     894 non-null    int64
#  2   Gender    894 non-null    object
#  3   Age       894 non-null    float64
#  4   SipSp     894 non-null    int64
#  5   ParCh     894 non-null    int64
#  6   Fare      894 non-null    float64
#  7   Emb       892 non-null    object
# dtypes: float64(2), int32(1), int64(3), object(2)
# memory usage: 52.5+ KB

# %%
titanic.isna().any(axis = 0)
# Out:
# Survived    False
# Class       False
# Gender      False
# Age         False
# SipSp       False
# ParCh       False
# Fare        False
# Emb          True
# dtype: bool

# %%
titanic["Emb"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 889    C
# 890    Q
# 891    S
# 892    S
# 893    S
# Name: Emb, Length: 894, dtype: object

# %%
titanic["Emb"] = titanic["Emb"].fillna(, inplace = True)

# %% [markdown]
# # **Detection of Duplicates**

# %%
alphabet = pd.DataFrame(["a", "b", "c", "c", "d", "e", "f", "g", "g", "g"], columns = ["Aplhbets"])

# %%
alphabet
# Out:
#   Aplhbets
# 0        a
# 1        b
# 2        c
# 3        c
# 4        d
# 5        e
# 6        f
# 7        g
# 8        g
# 9        g

# %%
alphabet.duplicated(keep = False)
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# 7     True
# 8     True
# 9     True
# dtype: bool

# %%
alphabet[alphabet.duplicated(keep = False)]
# Out:
#   Aplhbets
# 2        c
# 3        c
# 7        g
# 8        g
# 9        g
